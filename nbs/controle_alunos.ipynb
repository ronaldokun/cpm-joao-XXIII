# %%
import os, sys

#path = os.path.abspath(os.path.join(os.path.dirname('__file__')), '..')
path = '/home/ronaldo/projects/programming/cpm'
#sys.path.insert(0, path)

os.chdir(path)

import pandas as pd

from cpm import functions as f

from cpm.variables import *

# Every time we change a module they are reload before executing 
# %reload_ext autoreload
# %autoreload 2

# %%
path
# Out:
# '/home/ronaldo/projects/programming/cpm'

# %%
listas = f.carrega_listas()

# %%
turmas = f.load_turmas()

# %%
notas = f.carrega_notas()

# %%
notas
# Out:
# [autoreload of cpm.functions failed: Traceback (most recent call last):
#   File "/home/ronaldo/miniconda3/envs/cpm/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/ronaldo/miniconda3/envs/cpm/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 376, in superreload
#     module = reload(module)
#   File "/home/ronaldo/miniconda3/envs/cpm/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/ronaldo/miniconda3/envs/cpm/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/ronaldo/projects/programming/cpm/cpm/functions.py", line 120
#     skiprows: Sequence = None,
#            ^
# SyntaxError: invalid syntax
# ]
#                                      index Nome_Completo Attendance  \
# 0          Ana Carolina Ribeiro dos Santos           2.5      0.625
# 1                  Clayvon da Silva Casado        7.1875      8.125
# 2             Daniele Santos Silva Basilio         8.125        7.5
# 3              Eliane Alves Ferreira Pires           7.5      4.375
# 4              Felipe Kenui Gomes da Silva         9.375      8.125
# 5                     Jamile Lima da Silva         8.125      6.875
# 6                        Jean França Nunes        1.5625       1.25
# 7                  Jéssica Osko de Almeida           7.5       8.75
# 8                         Joyce Souza Lima        7.8125        7.5
# 9               Larissa de Jesus Cerqueira           2.5      3.125
# 10               Milena Lais Leite Pereira         5.625       6.25
# 11                 Rafael Albuquerque Mori        9.6875      11.25
# 12            Samitha Ribeiro França Nunes        1.5625       1.25
# 13              Valéria Xavier de Oliveira          8.75        7.5
# 14                Celso Gaspar Vasconcelos             0          0
# 15                   Kennedy Sousa Pereira           7.5       8.75
# 16       Isabella Larocca Candido da Silva         9.375      8.125
# 17                                     NaN             0          0
# 18                                     NaN             0          0
# 19                                     NaN             0          0
# 20                                     NaN             0          0
# 21                                     NaN             0          0
# 22                                     NaN             0          0
# 23                                     NaN             0          0
# 24                                     NaN             0          0
# 0                         Fernanda Bezerra         0.625          0
# 1                            Fernando Mori        8.4375      8.125
# 2              Graziela Cardoso dos Santos           7.5      6.875
# 3                 Isaac de Paula Rodrigues         9.375       6.25
# 4                      Jair Armando Chaves          1.25          0
# ..                                     ...           ...        ...
# 20                                     NaN             0          0
# 21                                     NaN             0          0
# 22                                     NaN             0          0
# 23                                     NaN             0          0
# 24                                     NaN             0          0
# 0                  Ana Luiza Neris Santana         6.875       6.25
# 9                 6.4                   0                           0
# 10  6.666666666666667                   0                           0
# 11                8.4                   0                           0
# 12                7.6                   0                           0
# 13                  8                   0                           0
# 14  7.666666666666667                   0                           0
# 15                6.8                   6                           0
# 16                  0                   0                           0
# 17                  0                   0                           0
# 18                  0                   0                           0
# 19                  0                   0                           0
# 20                  0                   0                           0
# 21                  0                   0                           0
# 22                  0                   0                           0
# 23                  0                   0                           0
# 24                  0                   0                           0
#
#                 Extras Final_Score   Turma
# 0               2.0125                  A1
# 1    8.606488095238095                  A1
# 2    6.965833333333334                  A1
# 3               5.0475                  A1
# 4    7.026666666666666                  A1
# 5    9.056190476190476                  A1
# 6              1.28125                  A1
# 7    6.171666666666667                  A1
# 8              8.90125                  A1
# 9   1.9291666666666667                  A1
# 10              5.6675                  A1
# 11   8.526527777777778                  A1
# 12             1.28125                  A1
# 13   8.062142857142858                  A1
# 14                 0.2                  A1
# 15    9.07595238095238                  A1
# 16               8.555                  A1
# 17                   0                  A1
# 18                   0                  A1
# 19                   0                  A1
# 20                   0                  A1
# 21                   0                  A1
# 22                   0                  A1
# 23                   0                  A1
# 24                   0                  A1
# 0               0.0625                  A2
# 1    6.059642857142857                  A2
# 2    8.359166666666667                  A2
# 3                6.894                  A2
# 4                0.525                  A2
# ..                 ...         ...     ...
# 20                   0                   J
# 21                   0                   J
# 22                   0                   J
# 23                   0                   J
# 24                   0                   J
# 0   2.7958333333333334              Teens2
# 1   2.4250000000000003              Teens2
# 2   2.9924999999999997              Teens2
# 3               2.1625              Teens2
# 4   2.6083333333333334              Teens2
# 5   2.8583333333333334              Teens2
# 6                2.555              Teens2
# 7   0.6666666666666667              Teens2
# 8   2.6166666666666667              Teens2
# 9   0.9525000000000001              Teens2
# 10  0.6666666666666667              Teens2
# 11               1.965              Teens2
# 12                1.26              Teens2
# 13               1.675              Teens2
# 14  1.2041666666666666              Teens2
# 15  1.6862500000000002              Teens2
# 16                   0              Teens2
# 17                   0              Teens2
# 18                   0              Teens2
# 19                   0              Teens2
# 20                   0              Teens2
# 21                   0              Teens2
# 22                   0              Teens2
# 23                   0              Teens2
# 24                   0              Teens2
#
# [425 rows x 11 columns]

# %%
alunos = f.load_df_from_sheet("J23_Alunos_Consolidado", "Alunos_2019_1S")

# %%
listas[["Total_Homework"]]

# %%
notas = ["Desistência", "Evasão"]

# %%
for col in notas:
    df = listas[[col]]
    col_index = alunos.columns.get_loc(col) + 4
    f.atualizar_coluna_df(df, "J23_Alunos_Consolidado", "Alunos_2019_1S", row=2, col=col_index)

# %%
def atualizar_coluna_df(df: pd.DataFrame, sheet: Union[str, gspread.Spreadsheet], aba: str, row: int, col: int):
    salva_aba_no_drive(df, plan, , aba, row, col)
